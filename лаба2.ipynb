# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

image_path = '/Users/daria/Desktop/унік/2 курс/1 семестр/прикладне програмування/код до лаб/лаба.jpg'
image = imageio.imread(image_path) 

enhanced_image = np.clip(1.5 * image - 50, 0, 255).astype(np.uint8)

r, g, b = enhanced_image[:, :, 0], enhanced_image[:, :, 1], enhanced_image[:, :, 2]

grayscale_image = np.dot(enhanced_image[..., :3], [0.299, 0.587, 0.114]).astype(np.uint8)

blurred_image = ndimage.gaussian_filter(grayscale_image, sigma=2)

edge_detected_image = ndimage.sobel(grayscale_image)

plt.figure(figsize=(12, 8))

plt.subplot(2, 3, 1)
plt.imshow(image)
plt.title('Original Image')

plt.subplot(2, 3, 2)
plt.imshow(enhanced_image)
plt.title('Enhanced Contrast')

plt.subplot(2, 3, 3)
plt.imshow(np.stack([r, g, b], axis=-1))
plt.title('RGB Components')

plt.subplot(2, 3, 4)
plt.imshow(grayscale_image, cmap='gray')
plt.title('Grayscale Image')

plt.subplot(2, 3, 5)
plt.imshow(blurred_image, cmap='gray')
plt.title('Blurred Image')

plt.subplot(2, 3, 6)
plt.imshow(edge_detected_image, cmap='gray')
plt.title('Edge Detection')

plt.show()
# Out:
# /var/folders/zf/fhkcdy917698j4zz6f5tg97c0000gn/T/ipykernel_60124/2553492368.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(image_path)

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 22  
M = 18

A = np.random.rand(N, M)

def find_nearest_value(z, A):
    closest_value = A.flat[np.abs(A - z).argmin()]
    return closest_value

mean_value = np.mean(A)
median_value = np.median(A)

plt.imshow(A, cmap='viridis')
plt.colorbar()
plt.show()

A[np.random.choice(N, size=5), np.random.choice(M, size=5)] = np.nan 

nan_indices = np.isnan(A)
A[nan_indices] = np.nanmean(A)

normalized_A = (A - np.nanmin(A)) / (np.nanmax(A) - np.nanmin(A))

plt.imshow(normalized_A, cmap='viridis')
plt.colorbar()
plt.show()
